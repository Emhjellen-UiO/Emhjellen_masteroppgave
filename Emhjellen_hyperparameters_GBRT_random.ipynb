# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# %%
train_X = pd.read_excel('ML_training_features.xlsx')
train_y = pd.read_excel('ML_training_target.xlsx')

# %%
validation_X = pd.read_excel('ML_validation_features.xlsx')
validation_y = pd.read_excel('ML_validation_target.xlsx')

# %%
validation_y = validation_y['ReleaseArea']
train_y = train_y['ReleaseArea']

# %%
# feature combinations
p1 = ['Slope']

p2 = ['Slope','Elevation']

p3 = ['Slope','North','East','North East','North West','South','South East','South West','West']

p4 = ['Slope','Elevation','Plan_curv','Profile_curv','TRI','Distance_to_roads']

p5 = ['Slope','Elevation','Plan_curv','Profile_curv','TRI','Flow_dir','Flow_acc','Distance_to_roads']

p6 = ['Slope','Elevation','Plan_curv','Profile_curv','TRI']

p7 = ['Elevation','North','East','North East','North West','South','South East','South West','West','Plan_curv','Profile_curv','TRI','Flow_dir','Flow_acc','Distance_to_roads']

p8 = ['Slope','Elevation','North','East','North East','North West','South','South East','South West','West','Plan_curv','Profile_curv','TRI','Flow_dir','Flow_acc','Distance_to_roads',
      'Granite','Granodiorite','Tonalite','Trondhjemite','Syenite','Monzonite','Monzodiorite','Quartz diorite','Diorite','Gabbro','Norite','Peridotite','Pyroksenite','Charnockite','Mangerite','Anorthosite','Mafic dyke (Diabase, Dolerite)','Pegmatite/aplite','Felsic volcanic rock','Rhyolite','Dacite','Intermediate volcanic rock','Andesite','Mafic volcanic rock','Basalt',
                  'Pyroclastic rock','Volcanic breccia','Siltstone','Sandstone','Greywacke','Arkose','Konglomerate','Sedimentary breccia','Limestone','Tuffite','Shale','Phyllite','Mica schist','Garnet mica schist','Calcareous phyllite','Calcareous mica schist','Amphibole schist','Graphitic schist','Calcite marble',
                 'Metasandstone','Metagreywacke','Meta-arkose','Quartzite','Quartz schist','Mica gneiss','Calc-silicate rock','Amphibole gneiss','Granitic gneiss','Granodioritic gneiss','Tonalitic gneiss','Quartz dioritic gneiss','Monzonitic gneiss','Dioritic gneis','Orthopyroxene gneiss','Migmatite','Augengneiss',
                    'Banded gneiss','Greenschist','Greenstone','Amphibolite','Metagabbro','Eclogite','Serpentinite','Mylonite/Phyllonite','Cataclasite']

feature_combinations = [p1,p2,p3,p4,p5,p6,p7,p8]

# %%
best_params = []
cv_results = []
best_score = []
parameter_setting = []

for i in feature_combinations:
    
    X_train = train_X[i]
    
    
    AUTO_SCALING = True
    if AUTO_SCALING:
        scaler = StandardScaler()
        scaler.fit(X_train)
        X_training = scaler.transform(X_train)
        
    clf = GradientBoostingClassifier(random_state=0)

    
    param_grid = {"n_estimators": np.arange(70, 120, 1),
              "learning_rate": np.arange(0.10, 0.30, 0.02),
              'max_depth':np.arange(1,15,1)}
    
    clf = RandomizedSearchCV(estimator=clf, param_distributions=param_grid,verbose=3, cv = 5,scoring = 'f1')
    clf.fit(X_training, train_y)
    
    best_params.append(clf.best_params_)
    cv_results.append(clf.cv_results_)
    best_score.append(clf.best_score_)
    parameter_setting.append(clf.cv_results_['params'][clf.best_index_])
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=97; total time=   0.5s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=97; total time=   0.5s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=97; total time=   0.6s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=97; total time=   0.5s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=97; total time=   0.5s
# [CV 1/5] END learning_rate=0.18000000000000002, max_depth=7, n_estimators=116; total time=   3.9s
# [CV 2/5] END learning_rate=0.18000000000000002, max_depth=7, n_estimators=116; total time=   3.9s
# [CV 3/5] END learning_rate=0.18000000000000002, max_depth=7, n_estimators=116; total time=   4.0s
# [CV 4/5] END learning_rate=0.18000000000000002, max_depth=7, n_estimators=116; total time=   4.1s
# [CV 5/5] END learning_rate=0.18000000000000002, max_depth=7, n_estimators=116; total time=   4.0s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=91; total time=   0.6s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=91; total time=   0.7s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=91; total time=   0.8s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=91; total time=   0.6s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=91; total time=   0.6s
# [CV 1/5] END learning_rate=0.14, max_depth=5, n_estimators=73; total time=   2.4s
# [CV 2/5] END learning_rate=0.14, max_depth=5, n_estimators=73; total time=   2.3s
# [CV 3/5] END learning_rate=0.14, max_depth=5, n_estimators=73; total time=   2.0s
# [CV 4/5] END learning_rate=0.14, max_depth=5, n_estimators=73; total time=   2.2s
# [CV 5/5] END learning_rate=0.14, max_depth=5, n_estimators=73; total time=   2.2s
# [CV 1/5] END learning_rate=0.1, max_depth=9, n_estimators=108; total time=   7.2s
# [CV 2/5] END learning_rate=0.1, max_depth=9, n_estimators=108; total time=   5.3s
# [CV 3/5] END learning_rate=0.1, max_depth=9, n_estimators=108; total time=   5.4s
# [CV 4/5] END learning_rate=0.1, max_depth=9, n_estimators=108; total time=   5.6s
# [CV 5/5] END learning_rate=0.1, max_depth=9, n_estimators=108; total time=   8.9s
# [CV 1/5] END learning_rate=0.14, max_depth=12, n_estimators=77; total time=   6.0s
# [CV 2/5] END learning_rate=0.14, max_depth=12, n_estimators=77; total time=   4.7s
# [CV 3/5] END learning_rate=0.14, max_depth=12, n_estimators=77; total time=   5.0s
# [CV 4/5] END learning_rate=0.14, max_depth=12, n_estimators=77; total time=   5.3s
# [CV 5/5] END learning_rate=0.14, max_depth=12, n_estimators=77; total time=   6.1s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=90; total time=   2.8s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=90; total time=   3.4s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=90; total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=90; total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=90; total time=   2.0s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=92; total time=   7.6s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=92; total time=   6.4s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=92; total time=   5.7s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=92; total time=   5.4s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=92; total time=   5.4s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=78; total time=   2.2s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=78; total time=   2.3s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=78; total time=   2.2s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=78; total time=   2.2s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=78; total time=   2.2s
# [CV 1/5] END learning_rate=0.24000000000000002, max_depth=13, n_estimators=115; total time=   7.6s
# [CV 2/5] END learning_rate=0.24000000000000002, max_depth=13, n_estimators=115; total time=   8.3s
# [CV 3/5] END learning_rate=0.24000000000000002, max_depth=13, n_estimators=115; total time=   8.8s
# [CV 4/5] END learning_rate=0.24000000000000002, max_depth=13, n_estimators=115; total time=   7.7s
# [CV 5/5] END learning_rate=0.24000000000000002, max_depth=13, n_estimators=115; total time=   7.3s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=13, n_estimators=104; total time=  12.4s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=13, n_estimators=104; total time=  11.4s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=13, n_estimators=104; total time=  11.2s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=13, n_estimators=104; total time=  11.4s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=13, n_estimators=104; total time=  11.2s
# [CV 1/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=78; total time=   7.6s
# [CV 2/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=78; total time=   7.6s
# [CV 3/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=78; total time=   7.7s
# [CV 4/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=78; total time=   8.2s
# [CV 5/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=78; total time=   8.6s
# [CV 1/5] END learning_rate=0.18000000000000002, max_depth=10, n_estimators=78; total time=   6.9s
# [CV 2/5] END learning_rate=0.18000000000000002, max_depth=10, n_estimators=78; total time=   7.1s
# [CV 3/5] END learning_rate=0.18000000000000002, max_depth=10, n_estimators=78; total time=   8.3s
# [CV 4/5] END learning_rate=0.18000000000000002, max_depth=10, n_estimators=78; total time=   6.2s
# [CV 5/5] END learning_rate=0.18000000000000002, max_depth=10, n_estimators=78; total time=   6.3s
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=111; total time=   1.7s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=111; total time=   1.6s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=111; total time=   1.7s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=111; total time=   1.7s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=111; total time=   1.7s
# [CV 1/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=110; total time=   9.0s
# [CV 2/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=110; total time=   9.1s
# [CV 3/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=110; total time=   8.8s
# [CV 4/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=110; total time=   8.8s
# [CV 5/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=110; total time=   8.6s
# [CV 1/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=87; total time=   6.7s
# [CV 2/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=87; total time=   6.6s
# [CV 3/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=87; total time=   6.6s
# [CV 4/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=87; total time=   6.4s
# [CV 5/5] END learning_rate=0.24000000000000002, max_depth=10, n_estimators=87; total time=   8.9s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=83; total time=   4.2s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=83; total time=   3.5s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=83; total time=   4.3s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=83; total time=   3.1s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=83; total time=   3.6s
# [CV 1/5] END learning_rate=0.14, max_depth=14, n_estimators=106; total time=  15.7s
# [CV 2/5] END learning_rate=0.14, max_depth=14, n_estimators=106; total time=  14.9s
# [CV 3/5] END learning_rate=0.14, max_depth=14, n_estimators=106; total time=  15.6s
# [CV 4/5] END learning_rate=0.14, max_depth=14, n_estimators=106; total time=  16.8s
# [CV 5/5] END learning_rate=0.14, max_depth=14, n_estimators=106; total time=  12.9s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=71; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=71; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=71; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=71; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=71; total time=   0.7s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=113; total time=   7.9s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=113; total time=   8.1s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=113; total time=   9.3s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=113; total time=   9.0s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=113; total time=  10.5s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.28, max_depth=7, n_estimators=94; total time=   4.6s
# [CV 2/5] END learning_rate=0.28, max_depth=7, n_estimators=94; total time=   3.6s
# [CV 3/5] END learning_rate=0.28, max_depth=7, n_estimators=94; total time=   3.6s
# [CV 4/5] END learning_rate=0.28, max_depth=7, n_estimators=94; total time=   3.7s
# [CV 5/5] END learning_rate=0.28, max_depth=7, n_estimators=94; total time=   3.8s
# [CV 1/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=80; total time=   5.2s
# [CV 2/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=80; total time=   5.2s
# [CV 3/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=80; total time=   5.2s
# [CV 4/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=80; total time=   5.4s
# [CV 5/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=80; total time=   6.1s
# [CV 1/5] END learning_rate=0.12000000000000001, max_depth=4, n_estimators=85; total time=   1.9s
# [CV 2/5] END learning_rate=0.12000000000000001, max_depth=4, n_estimators=85; total time=   1.9s
# [CV 3/5] END learning_rate=0.12000000000000001, max_depth=4, n_estimators=85; total time=   1.8s
# [CV 4/5] END learning_rate=0.12000000000000001, max_depth=4, n_estimators=85; total time=   1.9s
# [CV 5/5] END learning_rate=0.12000000000000001, max_depth=4, n_estimators=85; total time=   1.9s
# [CV 1/5] END learning_rate=0.14, max_depth=13, n_estimators=111; total time=   8.7s
# [CV 2/5] END learning_rate=0.14, max_depth=13, n_estimators=111; total time=   8.6s
# [CV 3/5] END learning_rate=0.14, max_depth=13, n_estimators=111; total time=   8.9s
# [CV 4/5] END learning_rate=0.14, max_depth=13, n_estimators=111; total time=  12.0s
# [CV 5/5] END learning_rate=0.14, max_depth=13, n_estimators=111; total time=  10.8s
# [CV 1/5] END learning_rate=0.14, max_depth=11, n_estimators=111; total time=   9.7s
# [CV 2/5] END learning_rate=0.14, max_depth=11, n_estimators=111; total time=  11.1s
# [CV 3/5] END learning_rate=0.14, max_depth=11, n_estimators=111; total time=   8.1s
# [CV 4/5] END learning_rate=0.14, max_depth=11, n_estimators=111; total time=   8.1s
# [CV 5/5] END learning_rate=0.14, max_depth=11, n_estimators=111; total time=   8.0s
# [CV 1/5] END learning_rate=0.28, max_depth=1, n_estimators=98; total time=   0.8s
# [CV 2/5] END learning_rate=0.28, max_depth=1, n_estimators=98; total time=   2.0s
# [CV 3/5] END learning_rate=0.28, max_depth=1, n_estimators=98; total time=   1.2s
# [CV 4/5] END learning_rate=0.28, max_depth=1, n_estimators=98; total time=   3.0s
# [CV 5/5] END learning_rate=0.28, max_depth=1, n_estimators=98; total time=   2.2s
# [CV 1/5] END learning_rate=0.18000000000000002, max_depth=6, n_estimators=83; total time=   4.0s
# [CV 2/5] END learning_rate=0.18000000000000002, max_depth=6, n_estimators=83; total time=   2.8s
# [CV 3/5] END learning_rate=0.18000000000000002, max_depth=6, n_estimators=83; total time=   3.1s
# [CV 4/5] END learning_rate=0.18000000000000002, max_depth=6, n_estimators=83; total time=   2.7s
# [CV 5/5] END learning_rate=0.18000000000000002, max_depth=6, n_estimators=83; total time=   2.6s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=106; total time=   2.8s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=106; total time=   3.1s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=106; total time=   2.8s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=106; total time=   3.6s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=106; total time=   3.8s
# [CV 1/5] END learning_rate=0.18000000000000002, max_depth=9, n_estimators=84; total time=   5.0s
# [CV 2/5] END learning_rate=0.18000000000000002, max_depth=9, n_estimators=84; total time=   5.0s
# [CV 3/5] END learning_rate=0.18000000000000002, max_depth=9, n_estimators=84; total time=   5.7s
# [CV 4/5] END learning_rate=0.18000000000000002, max_depth=9, n_estimators=84; total time=   5.2s
# [CV 5/5] END learning_rate=0.18000000000000002, max_depth=9, n_estimators=84; total time=   5.8s
# [CV 1/5] END learning_rate=0.2, max_depth=1, n_estimators=74; total time=   0.8s
# [CV 2/5] END learning_rate=0.2, max_depth=1, n_estimators=74; total time=   0.5s
# [CV 3/5] END learning_rate=0.2, max_depth=1, n_estimators=74; total time=   0.8s
# [CV 4/5] END learning_rate=0.2, max_depth=1, n_estimators=74; total time=   0.7s
# [CV 5/5] END learning_rate=0.2, max_depth=1, n_estimators=74; total time=   0.6s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.14, max_depth=4, n_estimators=88; total time=   7.3s
# [CV 2/5] END learning_rate=0.14, max_depth=4, n_estimators=88; total time=   6.3s
# [CV 3/5] END learning_rate=0.14, max_depth=4, n_estimators=88; total time=   6.4s
# [CV 4/5] END learning_rate=0.14, max_depth=4, n_estimators=88; total time=   6.6s
# [CV 5/5] END learning_rate=0.14, max_depth=4, n_estimators=88; total time=   6.6s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=84; total time=   1.7s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=84; total time=   1.8s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=84; total time=   1.6s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=84; total time=   1.8s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=84; total time=   1.7s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=83; total time=  13.9s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=83; total time=  14.4s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=83; total time=  14.2s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=83; total time=  15.0s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=9, n_estimators=83; total time=  14.4s
# [CV 1/5] END learning_rate=0.26, max_depth=5, n_estimators=88; total time=   8.3s
# [CV 2/5] END learning_rate=0.26, max_depth=5, n_estimators=88; total time=   7.9s
# [CV 3/5] END learning_rate=0.26, max_depth=5, n_estimators=88; total time=   7.8s
# [CV 4/5] END learning_rate=0.26, max_depth=5, n_estimators=88; total time=   7.8s
# [CV 5/5] END learning_rate=0.26, max_depth=5, n_estimators=88; total time=   7.8s
# [CV 1/5] END learning_rate=0.12000000000000001, max_depth=7, n_estimators=79; total time=   9.9s
# [CV 2/5] END learning_rate=0.12000000000000001, max_depth=7, n_estimators=79; total time=  10.7s
# [CV 3/5] END learning_rate=0.12000000000000001, max_depth=7, n_estimators=79; total time=   9.8s
# [CV 4/5] END learning_rate=0.12000000000000001, max_depth=7, n_estimators=79; total time=   9.8s
# [CV 5/5] END learning_rate=0.12000000000000001, max_depth=7, n_estimators=79; total time=   9.5s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=12, n_estimators=87; total time=  19.9s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=12, n_estimators=87; total time=  20.4s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=12, n_estimators=87; total time=  19.8s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=12, n_estimators=87; total time=  19.7s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=12, n_estimators=87; total time=  19.5s
# [CV 1/5] END learning_rate=0.26, max_depth=5, n_estimators=111; total time=   9.6s
# [CV 2/5] END learning_rate=0.26, max_depth=5, n_estimators=111; total time=   9.6s
# [CV 3/5] END learning_rate=0.26, max_depth=5, n_estimators=111; total time=   9.6s
# [CV 4/5] END learning_rate=0.26, max_depth=5, n_estimators=111; total time=   9.7s
# [CV 5/5] END learning_rate=0.26, max_depth=5, n_estimators=111; total time=   9.9s
# [CV 1/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=93; total time=  19.0s
# [CV 2/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=93; total time=  18.8s
# [CV 3/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=93; total time=  18.9s
# [CV 4/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=93; total time=  20.5s
# [CV 5/5] END learning_rate=0.18000000000000002, max_depth=11, n_estimators=93; total time=  18.9s
# [CV 1/5] END learning_rate=0.28, max_depth=9, n_estimators=81; total time=  13.4s
# [CV 2/5] END learning_rate=0.28, max_depth=9, n_estimators=81; total time=  13.1s
# [CV 3/5] END learning_rate=0.28, max_depth=9, n_estimators=81; total time=  14.3s
# [CV 4/5] END learning_rate=0.28, max_depth=9, n_estimators=81; total time=  13.5s
# [CV 5/5] END learning_rate=0.28, max_depth=9, n_estimators=81; total time=  13.1s
# [CV 1/5] END learning_rate=0.12000000000000001, max_depth=8, n_estimators=105; total time=  15.0s
# [CV 2/5] END learning_rate=0.12000000000000001, max_depth=8, n_estimators=105; total time=  15.2s
# [CV 3/5] END learning_rate=0.12000000000000001, max_depth=8, n_estimators=105; total time=  14.9s
# [CV 4/5] END learning_rate=0.12000000000000001, max_depth=8, n_estimators=105; total time=  15.1s
# [CV 5/5] END learning_rate=0.12000000000000001, max_depth=8, n_estimators=105; total time=  15.0s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=80; total time=   7.7s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=80; total time=   7.6s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=80; total time=   7.6s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=80; total time=   7.7s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=80; total time=   8.1s
# [CV 1/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=116; total time=   2.5s
# [CV 2/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=116; total time=   2.4s
# [CV 3/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=116; total time=   2.4s
# [CV 4/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=116; total time=   2.5s
# [CV 5/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=116; total time=   2.4s
# [CV 1/5] END learning_rate=0.14, max_depth=12, n_estimators=94; total time=  22.8s
# [CV 2/5] END learning_rate=0.14, max_depth=12, n_estimators=94; total time=  23.1s
# [CV 3/5] END learning_rate=0.14, max_depth=12, n_estimators=94; total time=  22.8s
# [CV 4/5] END learning_rate=0.14, max_depth=12, n_estimators=94; total time=  23.0s
# [CV 5/5] END learning_rate=0.14, max_depth=12, n_estimators=94; total time=  23.4s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=14, n_estimators=85; total time=  27.8s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=14, n_estimators=85; total time=  26.0s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=14, n_estimators=85; total time=  25.7s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=14, n_estimators=85; total time=  25.9s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=14, n_estimators=85; total time=  28.1s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=9, n_estimators=114; total time=  19.6s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=9, n_estimators=114; total time=  20.4s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=9, n_estimators=114; total time=  37.4s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=9, n_estimators=114; total time=  26.5s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=9, n_estimators=114; total time=  29.4s
# [CV 1/5] END learning_rate=0.2, max_depth=1, n_estimators=118; total time=   3.4s
# [CV 2/5] END learning_rate=0.2, max_depth=1, n_estimators=118; total time=   3.7s
# [CV 3/5] END learning_rate=0.2, max_depth=1, n_estimators=118; total time=   2.8s
# [CV 4/5] END learning_rate=0.2, max_depth=1, n_estimators=118; total time=   3.7s
# [CV 5/5] END learning_rate=0.2, max_depth=1, n_estimators=118; total time=   3.0s
# [CV 1/5] END learning_rate=0.14, max_depth=13, n_estimators=104; total time=  39.1s
# [CV 2/5] END learning_rate=0.14, max_depth=13, n_estimators=104; total time=  34.9s
# [CV 3/5] END learning_rate=0.14, max_depth=13, n_estimators=104; total time=  37.1s
# [CV 4/5] END learning_rate=0.14, max_depth=13, n_estimators=104; total time=  33.1s
# [CV 5/5] END learning_rate=0.14, max_depth=13, n_estimators=104; total time=  33.4s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=109; total time=  11.0s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=109; total time=  10.6s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=109; total time=  10.4s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=109; total time=  10.4s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=5, n_estimators=109; total time=  10.3s
# [CV 1/5] END learning_rate=0.26, max_depth=5, n_estimators=95; total time=   9.3s
# [CV 2/5] END learning_rate=0.26, max_depth=5, n_estimators=95; total time=   9.6s
# [CV 3/5] END learning_rate=0.26, max_depth=5, n_estimators=95; total time=  11.2s
# [CV 4/5] END learning_rate=0.26, max_depth=5, n_estimators=95; total time=  10.6s
# [CV 5/5] END learning_rate=0.26, max_depth=5, n_estimators=95; total time=   9.2s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=3, n_estimators=99; total time=   5.7s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=3, n_estimators=99; total time=   5.8s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=3, n_estimators=99; total time=   5.9s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=3, n_estimators=99; total time=   6.1s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=3, n_estimators=99; total time=   5.8s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=4, n_estimators=113; total time=   7.9s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=4, n_estimators=113; total time=   7.0s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=4, n_estimators=113; total time=   7.0s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=4, n_estimators=113; total time=   8.0s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=4, n_estimators=113; total time=   8.8s
# [CV 1/5] END learning_rate=0.26, max_depth=6, n_estimators=119; total time=  15.5s
# [CV 2/5] END learning_rate=0.26, max_depth=6, n_estimators=119; total time=  13.9s
# [CV 3/5] END learning_rate=0.26, max_depth=6, n_estimators=119; total time=  12.4s
# [CV 4/5] END learning_rate=0.26, max_depth=6, n_estimators=119; total time=  11.6s
# [CV 5/5] END learning_rate=0.26, max_depth=6, n_estimators=119; total time=  12.7s
# [CV 1/5] END learning_rate=0.28, max_depth=3, n_estimators=81; total time=   4.3s
# [CV 2/5] END learning_rate=0.28, max_depth=3, n_estimators=81; total time=   4.7s
# [CV 3/5] END learning_rate=0.28, max_depth=3, n_estimators=81; total time=   4.3s
# [CV 4/5] END learning_rate=0.28, max_depth=3, n_estimators=81; total time=   5.4s
# [CV 5/5] END learning_rate=0.28, max_depth=3, n_estimators=81; total time=   4.3s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=70; total time=   1.3s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=70; total time=   1.2s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=70; total time=   1.4s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=70; total time=   2.2s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=1, n_estimators=70; total time=   2.0s
# [CV 1/5] END learning_rate=0.1, max_depth=9, n_estimators=76; total time=  14.3s
# [CV 2/5] END learning_rate=0.1, max_depth=9, n_estimators=76; total time=  11.3s
# [CV 3/5] END learning_rate=0.1, max_depth=9, n_estimators=76; total time=  11.9s
# [CV 4/5] END learning_rate=0.1, max_depth=9, n_estimators=76; total time=  12.1s
# [CV 5/5] END learning_rate=0.1, max_depth=9, n_estimators=76; total time=  15.3s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=10, n_estimators=95; total time=  17.2s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=10, n_estimators=95; total time=  18.1s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=10, n_estimators=95; total time=  17.9s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=10, n_estimators=95; total time=  16.1s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=10, n_estimators=95; total time=  16.1s
# [CV 1/5] END learning_rate=0.2, max_depth=4, n_estimators=89; total time=   5.7s
# [CV 2/5] END learning_rate=0.2, max_depth=4, n_estimators=89; total time=   6.0s
# [CV 3/5] END learning_rate=0.2, max_depth=4, n_estimators=89; total time=   6.3s
# [CV 4/5] END learning_rate=0.2, max_depth=4, n_estimators=89; total time=   7.0s
# [CV 5/5] END learning_rate=0.2, max_depth=4, n_estimators=89; total time=   6.2s
# [CV 1/5] END learning_rate=0.28, max_depth=5, n_estimators=87; total time=   7.4s
# [CV 2/5] END learning_rate=0.28, max_depth=5, n_estimators=87; total time=   7.1s
# [CV 3/5] END learning_rate=0.28, max_depth=5, n_estimators=87; total time=   7.2s
# [CV 4/5] END learning_rate=0.28, max_depth=5, n_estimators=87; total time=   6.9s
# [CV 5/5] END learning_rate=0.28, max_depth=5, n_estimators=87; total time=   7.4s
# [CV 1/5] END learning_rate=0.24000000000000002, max_depth=14, n_estimators=113; total time=  29.6s
# [CV 2/5] END learning_rate=0.24000000000000002, max_depth=14, n_estimators=113; total time=  28.6s
# [CV 3/5] END learning_rate=0.24000000000000002, max_depth=14, n_estimators=113; total time=  29.0s
# [CV 4/5] END learning_rate=0.24000000000000002, max_depth=14, n_estimators=113; total time=  29.5s
# [CV 5/5] END learning_rate=0.24000000000000002, max_depth=14, n_estimators=113; total time=  28.2s
# [CV 1/5] END learning_rate=0.28, max_depth=12, n_estimators=103; total time=  20.9s
# [CV 2/5] END learning_rate=0.28, max_depth=12, n_estimators=103; total time=  20.7s
# [CV 3/5] END learning_rate=0.28, max_depth=12, n_estimators=103; total time=  20.7s
# [CV 4/5] END learning_rate=0.28, max_depth=12, n_estimators=103; total time=  20.7s
# [CV 5/5] END learning_rate=0.28, max_depth=12, n_estimators=103; total time=  20.7s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.2, max_depth=11, n_estimators=106; total time=  24.6s
# [CV 2/5] END learning_rate=0.2, max_depth=11, n_estimators=106; total time=  23.2s
# [CV 3/5] END learning_rate=0.2, max_depth=11, n_estimators=106; total time=  23.5s
# [CV 4/5] END learning_rate=0.2, max_depth=11, n_estimators=106; total time=  23.3s
# [CV 5/5] END learning_rate=0.2, max_depth=11, n_estimators=106; total time=  22.9s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=119; total time=  13.3s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=119; total time=  13.9s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=119; total time=  13.5s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=119; total time=  13.5s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=119; total time=  13.8s
# [CV 1/5] END learning_rate=0.1, max_depth=14, n_estimators=109; total time=  34.7s
# [CV 2/5] END learning_rate=0.1, max_depth=14, n_estimators=109; total time=  45.0s
# [CV 3/5] END learning_rate=0.1, max_depth=14, n_estimators=109; total time=  42.6s
# [CV 4/5] END learning_rate=0.1, max_depth=14, n_estimators=109; total time=  41.3s
# [CV 5/5] END learning_rate=0.1, max_depth=14, n_estimators=109; total time=  39.0s
# [CV 1/5] END learning_rate=0.24000000000000002, max_depth=11, n_estimators=112; total time=  27.0s
# [CV 2/5] END learning_rate=0.24000000000000002, max_depth=11, n_estimators=112; total time=  27.6s
# [CV 3/5] END learning_rate=0.24000000000000002, max_depth=11, n_estimators=112; total time=  27.1s
# [CV 4/5] END learning_rate=0.24000000000000002, max_depth=11, n_estimators=112; total time=  26.1s
# [CV 5/5] END learning_rate=0.24000000000000002, max_depth=11, n_estimators=112; total time=  26.7s
# [CV 1/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=89; total time=   2.3s
# [CV 2/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=89; total time=   2.3s
# [CV 3/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=89; total time=   2.6s
# [CV 4/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=89; total time=   2.1s
# [CV 5/5] END learning_rate=0.12000000000000001, max_depth=1, n_estimators=89; total time=   2.4s
# [CV 1/5] END learning_rate=0.2, max_depth=11, n_estimators=80; total time=  31.1s
# [CV 2/5] END learning_rate=0.2, max_depth=11, n_estimators=80; total time=  18.0s
# [CV 3/5] END learning_rate=0.2, max_depth=11, n_estimators=80; total time=  18.7s
# [CV 4/5] END learning_rate=0.2, max_depth=11, n_estimators=80; total time=  21.8s
# [CV 5/5] END learning_rate=0.2, max_depth=11, n_estimators=80; total time=  18.1s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=8, n_estimators=102; total time=  20.1s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=8, n_estimators=102; total time=  19.9s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=8, n_estimators=102; total time=  16.6s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=8, n_estimators=102; total time=  17.3s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=8, n_estimators=102; total time=  18.8s
# [CV 1/5] END learning_rate=0.18000000000000002, max_depth=5, n_estimators=105; total time=  12.6s
# [CV 2/5] END learning_rate=0.18000000000000002, max_depth=5, n_estimators=105; total time=  11.4s
# [CV 3/5] END learning_rate=0.18000000000000002, max_depth=5, n_estimators=105; total time=  10.8s
# [CV 4/5] END learning_rate=0.18000000000000002, max_depth=5, n_estimators=105; total time=  12.8s
# [CV 5/5] END learning_rate=0.18000000000000002, max_depth=5, n_estimators=105; total time=  10.5s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=116; total time=   6.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=116; total time=   7.1s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=116; total time=   7.7s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=116; total time=   7.1s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=116; total time=   6.8s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=6, n_estimators=100; total time=  12.3s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=6, n_estimators=100; total time=  15.7s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=6, n_estimators=100; total time=  11.9s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=6, n_estimators=100; total time=  11.8s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=6, n_estimators=100; total time=  13.4s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=2, n_estimators=84; total time=   8.5s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=2, n_estimators=84; total time=   7.4s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=2, n_estimators=84; total time=   8.1s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=2, n_estimators=84; total time=   7.1s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=2, n_estimators=84; total time=   7.0s
# [CV 1/5] END learning_rate=0.16000000000000003, max_depth=6, n_estimators=113; total time=  25.2s
# [CV 2/5] END learning_rate=0.16000000000000003, max_depth=6, n_estimators=113; total time=  23.1s
# [CV 3/5] END learning_rate=0.16000000000000003, max_depth=6, n_estimators=113; total time=  25.8s
# [CV 4/5] END learning_rate=0.16000000000000003, max_depth=6, n_estimators=113; total time=  28.6s
# [CV 5/5] END learning_rate=0.16000000000000003, max_depth=6, n_estimators=113; total time=  25.0s
# [CV 1/5] END learning_rate=0.1, max_depth=11, n_estimators=88; total time=  31.6s
# [CV 2/5] END learning_rate=0.1, max_depth=11, n_estimators=88; total time=  43.3s
# [CV 3/5] END learning_rate=0.1, max_depth=11, n_estimators=88; total time=  34.2s
# [CV 4/5] END learning_rate=0.1, max_depth=11, n_estimators=88; total time=  34.0s
# [CV 5/5] END learning_rate=0.1, max_depth=11, n_estimators=88; total time=  33.5s
# [CV 1/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=97; total time=  44.8s
# [CV 2/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=97; total time=  44.7s
# [CV 3/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=97; total time=  39.9s
# [CV 4/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=97; total time=  40.5s
# [CV 5/5] END learning_rate=0.24000000000000002, max_depth=12, n_estimators=97; total time=  40.9s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=10, n_estimators=114; total time=  51.2s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=10, n_estimators=114; total time=  56.5s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=10, n_estimators=114; total time=  43.4s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=10, n_estimators=114; total time=  40.0s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=10, n_estimators=114; total time=  36.4s
# [CV 1/5] END learning_rate=0.22000000000000003, max_depth=12, n_estimators=82; total time=  35.0s
# [CV 2/5] END learning_rate=0.22000000000000003, max_depth=12, n_estimators=82; total time=  35.5s
# [CV 3/5] END learning_rate=0.22000000000000003, max_depth=12, n_estimators=82; total time=  37.8s
# [CV 4/5] END learning_rate=0.22000000000000003, max_depth=12, n_estimators=82; total time=  33.7s
# [CV 5/5] END learning_rate=0.22000000000000003, max_depth=12, n_estimators=82; total time=  34.2s
# [CV 1/5] END learning_rate=0.28, max_depth=14, n_estimators=100; total time=  44.1s
# [CV 2/5] END learning_rate=0.28, max_depth=14, n_estimators=100; total time=  44.5s
# [CV 3/5] END learning_rate=0.28, max_depth=14, n_estimators=100; total time=  44.5s
# [CV 4/5] END learning_rate=0.28, max_depth=14, n_estimators=100; total time=  44.3s
# [CV 5/5] END learning_rate=0.28, max_depth=14, n_estimators=100; total time=  44.9s
# [CV 1/5] END learning_rate=0.26, max_depth=3, n_estimators=112; total time=  12.5s
# [CV 2/5] END learning_rate=0.26, max_depth=3, n_estimators=112; total time=  12.7s
# [CV 3/5] END learning_rate=0.26, max_depth=3, n_estimators=112; total time=  12.2s
# [CV 4/5] END learning_rate=0.26, max_depth=3, n_estimators=112; total time=  12.8s
# [CV 5/5] END learning_rate=0.26, max_depth=3, n_estimators=112; total time=  13.3s
# [CV 1/5] END learning_rate=0.26, max_depth=12, n_estimators=85; total time=  31.7s
# [CV 2/5] END learning_rate=0.26, max_depth=12, n_estimators=85; total time=  32.5s
# [CV 3/5] END learning_rate=0.26, max_depth=12, n_estimators=85; total time=  32.0s
# [CV 4/5] END learning_rate=0.26, max_depth=12, n_estimators=85; total time=  31.1s
# [CV 5/5] END learning_rate=0.26, max_depth=12, n_estimators=85; total time=  31.2s
# [CV 1/5] END learning_rate=0.28, max_depth=1, n_estimators=114; total time=   5.7s
# [CV 2/5] END learning_rate=0.28, max_depth=1, n_estimators=114; total time=   5.8s
# [CV 3/5] END learning_rate=0.28, max_depth=1, n_estimators=114; total time=   5.4s
# [CV 4/5] END learning_rate=0.28, max_depth=1, n_estimators=114; total time=   5.4s
# [CV 5/5] END learning_rate=0.28, max_depth=1, n_estimators=114; total time=   5.6s

# %%
best_params_df = pd.DataFrame(best_params)
best_params_df.to_excel('GBRT_best_params_RandomSearch4.xlsx')

# %%
cv_results_df = pd.DataFrame(cv_results)
cv_results_df.to_excel('GBRT_cv_results_RandomSearch4.xlsx')

# %%
best_score_df = pd.DataFrame(best_score)
best_score_df.to_excel('GBRT_best_cv_scores_RandomSearch4.xlsx')
